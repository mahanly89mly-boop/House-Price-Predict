# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(".\\housing_data.csv")
df.head()
# Out:
#    id  area_sqft  bedrooms  bathrooms  floors  garage  year_built  \
# 0   1       1450         3          2       1       1        1998
# 1   2       2100         4          3       2       2        2005
# 2   3        890         2          1       1       0        1985
# 3   4       3200         5          4       2       2        2018
# 4   5       1750         3          2       1       1        2002
#
#    neighborhood_score  school_rating  distance_to_center_km  has_pool  \
# 0                 7.2            8.1                   12.4         0
# 1                 8.5            9.0                    5.2         1
# 2                 5.8            6.5                   18.7         0
# 3                 9.1            9.5                    3.1         1
# 4                 7.8            7.9                    9.8         0
#
#    has_garden  renovation_year  price_usd
# 0           1             2015     245000
# 1           1                0     420000
# ...

# %%
x = df.drop(["price_usd"], axis=1)
y = df["price_usd"]

# %%
x = np.array(x)
y = np.array(y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(x)
# Out:
# array([[-1.69774938, -0.4884664 , -0.24576958, -0.38490018, -0.88968025,
#         -0.13897232, -0.28858082, -0.31434508,  0.1697444 ,  0.27551486,
#         -0.75      ,  0.75      ,  1.22388019],
#        [-1.62845348,  0.3052915 ,  0.57346234,  0.57735027,  0.75787577,
#          1.01913032,  0.26944839,  0.69217857,  0.90421537, -0.85932894,
#          1.33333333,  0.75      , -0.81649393],
#        [-1.55915759, -1.17231935, -1.0650015 , -1.34715063, -0.88968025,
#         -1.29707495, -1.3249208 , -1.39829361, -1.13598177,  1.26850318,
#         -0.75      , -1.33333333,  1.21881723],
#        [-1.4898617 ,  1.64857409,  1.39269426,  1.53960072,  0.75787577,
#          1.01913032,  1.30578837,  1.15672794,  1.3122548 , -1.19032505,
#          1.33333333,  0.75      , -0.81649393],
#        [-1.4205658 , -0.1221166 , -0.24576958, -0.38490018, -0.88968025,
#         -0.13897232,  0.03029301,  0.1502043 ,  0.00652863, -0.13428985,
#         -0.75      ,  0.75      ,  1.22793056],
# ...

# %%
from sklearn.linear_model import LinearRegression
model_LR =  LinearRegression()
model_LR.fit(x, y)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(x , y , test_size=0.2)

# %%
from sklearn.ensemble import GradientBoostingClassifier
model = GradientBoostingClassifier()
model.fit(x ,y)
# Out:
# c:\Users\mahan.ly\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\ensemble\_gb.py:1524: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   check_classification_targets(y)
# GradientBoostingClassifier()

# %%
dfr = {
    "id" : np.random.randint(1,6),
    "area_sqft" : np.random.randint(800, 5000),
    "bedrooms" : np.random.randint(0,6),
    "bathrooms"	: np.random.randint(0,6),
    "floors" : np.random.randint(0,3),
    "garage" : np.random.randint(0,4),
    "year_built" : np.random.randint(1950,2026),
    "neighborhood_score" :  np.random.uniform(5.0,10.0,1),
    "school_rating" : np.random.uniform(5.0,10.0 ,1),
    "distance_to_center_km" : np.random.uniform(10.0,20.0 , 1),
    "has_pool" : 0,
    "has_garden" : 1,
    "renovation_year" : 0

}
result_df = pd.DataFrame(dfr)
result_df
# Out:
#    id  area_sqft  bedrooms  bathrooms  floors  garage  year_built  \
# 0   3       4830         2          1       1       0        1951
#
#    neighborhood_score  school_rating  distance_to_center_km  has_pool  \
# 0              8.8259       7.941609              14.179559         0
#
#    has_garden  renovation_year
# 0           1                0

# %%
df.head()
# Out:
#    id  area_sqft  bedrooms  bathrooms  floors  garage  year_built  \
# 0   1       1450         3          2       1       1        1998
# 1   2       2100         4          3       2       2        2005
# 2   3        890         2          1       1       0        1985
# 3   4       3200         5          4       2       2        2018
# 4   5       1750         3          2       1       1        2002
#
#    neighborhood_score  school_rating  distance_to_center_km  has_pool  \
# 0                 7.2            8.1                   12.4         0
# 1                 8.5            9.0                    5.2         1
# 2                 5.8            6.5                   18.7         0
# 3                 9.1            9.5                    3.1         1
# 4                 7.8            7.9                    9.8         0
#
#    has_garden  renovation_year  price_usd
# 0           1             2015     245000
# 1           1                0     420000
# ...

# %%
result_GBC = model.predict(result_df)
result_GBC = result_GBC[0]
print(f"Your house price is ${result_GBC}")
# Out:
# Your house price is $650000
# c:\Users\mahan.ly\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(

# %%
result_LR = model_LR.predict(result_df)
result_LR = result_LR[0]
print(f"Your house price is ${result_LR}")
# Out:
# Your house price is $1271620.5238043927
# c:\Users\mahan.ly\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
